# %%
import numpy as np
import pandas as pd
input = ['L68','L30','R48']
start = 50

# %%
f = open("input_q1.txt")
with open("input_q1.txt", 'r') as file:
        rotations = [line.strip() for line in file]

# %%
rotations[0]
# Out:
# 'R29'

# %%
last = 50
answers = []
for i in range(len(rotations)):
    print(i)
    if rotations[i][0] == 'R':
        last = np.mod(last + int(rotations[i][1:]),100)
        answers .append(last)
    else:
        last = np.mod(last - int(rotations[i][1:]), 100 )
        answers .append(last)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [45], line 5
#       2 answers = []
#       3 for i in range(len(rotations)):
# ----> 5     if input[i][0] == 'R':
#       6         last = np.mod(last + int(input[i][1:]),100)
#       7         answers .append(last)
#
# IndexError: list index out of range

# %%
## final answer
print('final answer:' , len([i for i in answers if i == 0]))
# Out:
# final answer: 1
